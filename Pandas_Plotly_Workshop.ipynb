# %% [markdown]
# <a href="https://colab.research.google.com/github/isishdzmr99-collab/week2_pandas/blob/main/Pandas_Plotly_Workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python for Public Policy — Session 2 Workbook
#
# **Data Manipulation with pandas + Interactive Charts with Plotly Express**

# %% [markdown]
# ## Lesson 1: Warm‑Up — Tiny DataFrame

# %%
import pandas as pd

toys = {
    'country': ['A', 'B', 'C'],
    'year': [2005, 2006, 2007],
    'arrivals': [10, 0, 5]
}

toy_df = pd.DataFrame(toys)
toy_df
# Out:
#   country  year  arrivals
# 0       A  2005        10
# 1       B  2006         0
# 2       C  2007         5

# %% [markdown]
# 🐻 PANDA time

# %%
import pandas as pd

# %%
toys_01 = {
    'country' : ['D', 'F', 'G'],
    'year': ['200', '2009', '2010'],
    'arrivals': [10, 0, 5]

}

# %%
toy_df = pd.DataFrame(toys_01)

# %%
import pandas as pd

toys_01 = {
    'country' : ['D', 'F', 'G'],
    'year': ['200', '2009', '2010'],
    'arrivals': [10, 0, 5]

}

toy_df = pd.DataFrame(toys_01)
toy_df
# Out:
#   country  year  arrivals
# 0       D   200        10
# 1       F  2009         0
# 2       G  2010         5

# %% [markdown]
# **Try it**
# - Show only the `country` and `arrivals` columns.
# - Filter rows where `arrivals` > 0.
# - Compute `pct_total` = arrivals / total * 100.

# %%
# Your code here
# toy_df[['country', 'arrivals']]
# toy_df[toy_df['arrivals'] > 0]
# toy_df['pct_total'] = toy_df['arrivals'] / toy_df['arrivals'].sum() * 100
# toy_df

# %% [markdown]
# ## Lesson 2: Load the Refugee Arrivals Dataset

# %% [markdown]
# **Data citation**
# - U.S. refugee arrivals (2005–2015), compiled from the Refugee Processing Center (via Jeremy Singer‑Vine).

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/GC-DRI/DRI24/main/uploads/pandas/refugee-arrivals-by-destination.csv'
refugee_df = pd.read_csv(url)
len(refugee_df), refugee_df.head(3)
# Out:
# (121245,
#     year       origin dest_state dest_city  arrivals
#  0  2005  Afghanistan    Alabama    Mobile         0
#  1  2006  Afghanistan    Alabama    Mobile         0
#  2  2007  Afghanistan    Alabama    Mobile         0)

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/GC-DRI/DRI24/main/uploads/pandas/refugee-arrivals-by-destination.csv'

# %%
refugee_df = pd.read_csv(url)

# %%
refugee_df
# Out:
#         year       origin dest_state  dest_city  arrivals
# 0       2005  Afghanistan    Alabama     Mobile         0
# 1       2006  Afghanistan    Alabama     Mobile         0
# 2       2007  Afghanistan    Alabama     Mobile         0
# 3       2008  Afghanistan    Alabama     Mobile         0
# 4       2009  Afghanistan    Alabama     Mobile         5
# ...      ...          ...        ...        ...       ...
# 121240  2011      Vietnam  Wisconsin  Milwaukee         0
# 121241  2012      Vietnam  Wisconsin  Milwaukee         4
# 121242  2013      Vietnam  Wisconsin  Milwaukee         2
# 121243  2014      Vietnam  Wisconsin  Milwaukee         0
# 121244  2015      Vietnam  Wisconsin  Milwaukee         0
#
# [121245 rows x 5 columns]

# %%
refugee_df.head(20)
# Out:
#     year       origin dest_state dest_city  arrivals
# 0   2005  Afghanistan    Alabama    Mobile         0
# 1   2006  Afghanistan    Alabama    Mobile         0
# 2   2007  Afghanistan    Alabama    Mobile         0
# 3   2008  Afghanistan    Alabama    Mobile         0
# 4   2009  Afghanistan    Alabama    Mobile         5
# 5   2010  Afghanistan    Alabama    Mobile         8
# 6   2011  Afghanistan    Alabama    Mobile         5
# 7   2012  Afghanistan    Alabama    Mobile         7
# 8   2013  Afghanistan    Alabama    Mobile         9
# 9   2014  Afghanistan    Alabama    Mobile         1
# 10  2015  Afghanistan    Alabama    Mobile         0
# 11  2005        Burma    Alabama    Auburn         0
# 12  2006        Burma    Alabama    Auburn         0
# 13  2007        Burma    Alabama    Auburn         0
# 14  2008        Burma    Alabama    Auburn         0
# 15  2009        Burma    Alabama    Auburn         0
# 16  2010        Burma    Alabama    Auburn         0
# 17  2007        Burma    Alabama    Auburn         0
# 18  2008        Burma    Alabama    Auburn         0
# 19  2009        Burma    Alabama    Auburn         0

# %%
refugee_df.tail(20)
# Out:
#         year   origin dest_state  dest_city  arrivals
# 121225  2007  Vietnam  Wisconsin    Madison         0
# 121226  2008  Vietnam  Wisconsin    Madison         0
# 121227  2009  Vietnam  Wisconsin    Madison         0
# 121228  2010  Vietnam  Wisconsin    Madison         0
# 121229  2011  Vietnam  Wisconsin    Madison         0
# 121230  2012  Vietnam  Wisconsin    Madison         4
# 121231  2013  Vietnam  Wisconsin    Madison         0
# 121232  2014  Vietnam  Wisconsin    Madison         1
# 121233  2015  Vietnam  Wisconsin    Madison         0
# 121234  2005  Vietnam  Wisconsin  Milwaukee         0
# 121235  2006  Vietnam  Wisconsin  Milwaukee         5
# 121236  2007  Vietnam  Wisconsin  Milwaukee        18
# 121237  2008  Vietnam  Wisconsin  Milwaukee        12
# 121238  2009  Vietnam  Wisconsin  Milwaukee         4
# 121239  2010  Vietnam  Wisconsin  Milwaukee         7
# 121240  2011  Vietnam  Wisconsin  Milwaukee         0
# 121241  2012  Vietnam  Wisconsin  Milwaukee         4
# 121242  2013  Vietnam  Wisconsin  Milwaukee         2
# 121243  2014  Vietnam  Wisconsin  Milwaukee         0
# 121244  2015  Vietnam  Wisconsin  Milwaukee         0

# %%
refugee_df[300:400]
# Out:
#      year   origin dest_state    dest_city  arrivals
# 300  2005     Iraq    Alabama        Foley         0
# 301  2006     Iraq    Alabama        Foley         0
# 302  2007     Iraq    Alabama        Foley         0
# 303  2008     Iraq    Alabama        Foley         0
# 304  2009     Iraq    Alabama        Foley         0
# ..    ...      ...        ...          ...       ...
# 395  2012  Liberia    Alabama   Montgomery         0
# 396  2013  Liberia    Alabama   Montgomery         0
# 397  2014  Liberia    Alabama   Montgomery         0
# 398  2015  Liberia    Alabama   Montgomery         0
# 399  2005  Liberia    Alabama  Phenix City         0
#
# [100 rows x 5 columns]

# %% [markdown]
# ### Quick exploration

# %%
refugee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121245 entries, 0 to 121244
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        121245 non-null  int64
#  1   origin      121245 non-null  object
#  2   dest_state  121245 non-null  object
#  3   dest_city   121245 non-null  object
#  4   arrivals    121245 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 4.6+ MB

# %%
refugee_df.sample(10)
# Out:
#         year       origin  dest_state      dest_city  arrivals
# 62702   2015         Laos   Minnesota    Minneapolis         0
# 36680   2008         Iran    Illinois  Franklin Park         0
# 18978   2005   Bangladesh    Colorado         Denver         0
# 104984  2013      Liberia       Texas        Garland         0
# 34620   2005     Ethiopia       Idaho     Twin Falls         0
# 100221  2013  Afghanistan       Texas       Richmond         0
# 51207   2015      Vietnam    Maryland      Baltimore         0
# 80519   2012   Uzbekistan    New York       Brooklyn         0
# 10678   2010         Iran  California    Yorba Linda         7
# 86898   2011         Iraq        Ohio    Mount Perry         0

# %% [markdown]
# ❗ 🐻 if you use SAMPLE it is going to be random

# %% [markdown]
# **Try it**
# - Show the last 7 rows.
# - Show the first 10 unique origins.

# %%
# refugee_df.tail(7)
# refugee_df['origin'].unique()[:10]

# %% [markdown]
# ## Lesson 3: Cleaning Basics

# %% [markdown]
# ### Data types
# Keep `year` as an integer for grouping. Add `year_dt` for date operations if needed.

# %%
refugee_df['year_dt'] = pd.to_datetime(refugee_df['year'], format='%Y')
refugee_df.dtypes
# Out:
# year                   int64
# origin                object
# dest_state            object
# dest_city             object
# arrivals               int64
# year_dt       datetime64[ns]
# dtype: object

# %%
refugee_df.dtypes
# Out:
# year                   int64
# origin                object
# dest_state            object
# dest_city             object
# arrivals               int64
# year_dt       datetime64[ns]
# dtype: object

# %% [markdown]
# ❗ ❗ ❗ ❗❗ ❗ ❗ ❗❗ ❗ ❗ ❗❗ ❗ ❗ ❗❗ ❗ ❗ ❗❗ ❗ ❗ ❗❗ ❗ ❗ ❗❗ ❗ ❗ ❗

# %%
refugee_df ['year_dt'] = pd.to_datetime(refugee_df ['year'], format= '%Y')

# %% [markdown]
# COMMENT needs [] ''

# %% [markdown]
# ### Duplicates

# %%
refugee_df[refugee_df.duplicated(keep=False)].head(10)
# Out:
#      year origin dest_state     dest_city  arrivals    year_dt
# 13   2007  Burma    Alabama        Auburn         0 2007-01-01
# 14   2008  Burma    Alabama        Auburn         0 2008-01-01
# 15   2009  Burma    Alabama        Auburn         0 2009-01-01
# 16   2010  Burma    Alabama        Auburn         0 2010-01-01
# 17   2007  Burma    Alabama        Auburn         0 2007-01-01
# 18   2008  Burma    Alabama        Auburn         0 2008-01-01
# 19   2009  Burma    Alabama        Auburn         0 2009-01-01
# 20   2010  Burma    Alabama        Auburn         0 2010-01-01
# 155  2013   Cuba    Alabama  Russellville         0 2013-01-01
# 156  2014   Cuba    Alabama  Russellville         0 2014-01-01

# %%
refugee_df[refugee_df.duplicated(keep=False)]
# Out:
#      year origin dest_state     dest_city  arrivals    year_dt
# 13   2007  Burma    Alabama        Auburn         0 2007-01-01
# 14   2008  Burma    Alabama        Auburn         0 2008-01-01
# 15   2009  Burma    Alabama        Auburn         0 2009-01-01
# 16   2010  Burma    Alabama        Auburn         0 2010-01-01
# 17   2007  Burma    Alabama        Auburn         0 2007-01-01
# 18   2008  Burma    Alabama        Auburn         0 2008-01-01
# 19   2009  Burma    Alabama        Auburn         0 2009-01-01
# 20   2010  Burma    Alabama        Auburn         0 2010-01-01
# 155  2013   Cuba    Alabama  Russellville         0 2013-01-01
# 156  2014   Cuba    Alabama  Russellville         0 2014-01-01
# 157  2015   Cuba    Alabama  Russellville         0 2015-01-01
# 158  2005   Cuba    Alabama      Theodore         0 2005-01-01
# 159  2006   Cuba    Alabama      Theodore         0 2006-01-01
# 160  2013   Cuba    Alabama  Russellville         0 2013-01-01
# 161  2014   Cuba    Alabama  Russellville         0 2014-01-01
# 162  2015   Cuba    Alabama  Russellville         0 2015-01-01
# 163  2005   Cuba    Alabama      Theodore         0 2005-01-01
# 164  2006   Cuba    Alabama      Theodore         0 2006-01-01
# 236  2012   Iran    Alabama        Mobile         1 2012-01-01
# 237  2013   Iran    Alabama        Mobile         6 2013-01-01
# 238  2014   Iran    Alabama        Mobile         3 2014-01-01
# 239  2015   Iran    Alabama        Mobile         5 2015-01-01
# 240  2005   Iran    Alabama        Pelham         0 2005-01-01
# 247  2012   Iran    Alabama        Mobile         1 2012-01-01
# 248  2013   Iran    Alabama        Mobile         6 2013-01-01
# 249  2014   Iran    Alabama        Mobile         3 2014-01-01
# 250  2015   Iran    Alabama        Mobile         5 2015-01-01
# 251  2005   Iran    Alabama        Pelham         0 2005-01-01
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['year'].plot(kind='hist', bins=20, title='year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['arrivals'].plot(kind='hist', bins=20, title='arrivals')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('origin').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('dest_city').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='year', y='arrivals', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['year_dt']
#   ys = series['arrivals']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_5.sort_values('year_dt', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('origin')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='origin', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('year_dt')
# _ = plt.ylabel('arrivals')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['year_dt']
#   ys = series['arrivals']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_6.sort_values('year_dt', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('dest_city')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='dest_city', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('year_dt')
# _ = plt.ylabel('arrivals')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['year_dt']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'year_dt'}, axis=1)
#               .sort_values('year_dt', ascending=True))
#   xs = counted['year_dt']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('year_dt', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('origin')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='origin', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('year_dt')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['year_dt']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'year_dt'}, axis=1)
#               .sort_values('year_dt', ascending=True))
#   xs = counted['year_dt']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('year_dt', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('dest_city')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='dest_city', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('year_dt')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_9['year'].plot(kind='line', figsize=(8, 4), title='year')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['arrivals'].plot(kind='line', figsize=(8, 4), title='arrivals')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['dest_city'].value_counts()
#     for x_label, grp in _df_11.groupby('origin')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('origin')
# _ = plt.ylabel('dest_city')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_12['origin'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_12, x='year', y='origin', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_13['dest_city'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_13, x='year', y='dest_city', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['origin'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='arrivals', y='origin', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['dest_city'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='arrivals', y='dest_city', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
refugee_df = refugee_df.drop_duplicates(keep='first')

# %%
refugee_df[refugee_df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [year, origin, dest_state, dest_city, arrivals, year_dt]
# Index: []

# %%
refugee_df = refugee_df.drop_duplicates(keep='first')
refugee_df.shape
# Out:
# (121231, 6)

# %% [markdown]
# ### Renaming & Selecting

# %%
refugee_df = refugee_df.rename(columns={'dest_state':'state', 'dest_city':'city'})
refugee_df.columns.tolist()
# Out:
# ['year', 'origin', 'state', 'city', 'arrivals', 'year_dt']

# %%
state_only_df = refugee_df[['state']]
state_series = refugee_df['state']
state_only_df.head(2), type(state_only_df), type(state_series)
# Out:
# (     state
#  0  Alabama
#  1  Alabama,
#  pandas.core.frame.DataFrame,
#  pandas.core.series.Series)

# %%
refugee_df.columns
# Out:
# Index(['year', 'origin', 'state', 'city', 'arrivals', 'year_dt'], dtype='object')

# %%
refugee_df =refugee_df.rename(columns={'dest_state' : 'state', 'dest_city': 'city'})

# %%
state_only_df = refugee_df[['state']]
state_series = refugee_df['state']
state_only_df.head(2), type(state_only_df), type(state_series)
# Out:
# (     state
#  0  Alabama
#  1  Alabama,
#  pandas.core.frame.DataFrame,
#  pandas.core.series.Series)

# %% [markdown]
# ❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗

# %%
refugee_df[['city', 'state', 'origin']].head(2)
# Out:
#      city    state       origin
# 0  Mobile  Alabama  Afghanistan
# 1  Mobile  Alabama  Afghanistan

# %% [markdown]
# [[]] double hard braquets is to call the info as data frame. Data frame: spreed sheet

# %% [markdown]
# **Try it**
# Using `.loc`, select rows where `origin == 'Iraq'` and columns `['year','state','city','arrivals']`. Then compute the mean of `arrivals`.

# %%
# iraq = refugee_df.loc[refugee_df['origin']=='Iraq', ['year','state','city','arrivals']]
# iraq_mean = iraq['arrivals'].mean()
# iraq.head(3), iraq_mean

# %% [markdown]
# ## Lesson 4: Grouping & Summarizing

# %%
by_origin = refugee_df.groupby('origin')
arrivals_sum = by_origin['arrivals'].sum()
arrivals_sum_sorted = arrivals_sum.sort_values(ascending=False)
arrivals_top20 = arrivals_sum_sorted.head(20)
arrivals_top20
# Out:
# origin
# Burma              151875
# Iraq               127326
# Bhutan              85316
# Somalia             71120
# Cuba                39946
# Iran                36683
# Dem. Rep. Congo     25493
# Russia              15656
# Eritrea             14645
# Sudan               12636
# Ukraine             11727
# Burundi             11152
# Vietnam             10769
# Liberia              9424
# Ethiopia             8487
# Afghanistan          6751
# Laos                 6609
# Moldova              4482
# Syria                2359
# Colombia             1956
# Name: arrivals, dtype: int64

# %%
by_origin = refugee_df.groupby('origin')

# %%
by_origin

# %%
arrivals_sum = by_origin['arrivals'].sum()

# %%
arrivals_sum
# Out:
# origin
# Afghanistan     6751
# Albania            3
# Algeria            6
# Angola            54
# Armenia          311
#                ...
# Venezuela         17
# Vietnam        10769
# Yemen            112
# Zambia             1
# Zimbabwe          67
# Name: arrivals, Length: 113, dtype: int64

# %%
arrivals_sum_sorted = arrivals_sum.sort_values(ascending=False)

# %%
arrivals_sum_sorted
# Out:
# origin
# Burma                   151875
# Iraq                    127326
# Bhutan                   85316
# Somalia                  71120
# Cuba                     39946
#                          ...
# Philippines                  1
# Sweden                       1
# United Kingdom               1
# United Arab Emirates         1
# Zambia                       1
# Name: arrivals, Length: 113, dtype: int64

# %%
arrivals_top20 = arrivals_sum_sorted.head(20)

# %%
arrivals_top20
# Out:
# origin
# Burma              151875
# Iraq               127326
# Bhutan              85316
# Somalia             71120
# Cuba                39946
# Iran                36683
# Dem. Rep. Congo     25493
# Russia              15656
# Eritrea             14645
# Sudan               12636
# Ukraine             11727
# Burundi             11152
# Vietnam             10769
# Liberia              9424
# Ethiopia             8487
# Afghanistan          6751
# Laos                 6609
# Moldova              4482
# Syria                2359
# Colombia             1956
# Name: arrivals, dtype: int64

# %%
pd.set_option('display.max_rows', None)

# %%
arrivals_sum
# Out:
# origin
# Afghanistan                         6751
# Albania                                3
# Algeria                                6
# Angola                                54
# Armenia                              311
# Azerbaijan                           512
# Bangladesh                            10
# Belarus                             1565
# Benin                                  2
# Bhutan                             85316
# Bosnia and Herzegovina                36
# Bulgaria                               1
# Burkina Faso (UVolta)                  7
# Burma                             151875
# Burundi                            11152
# Cambodia                             147
# Cameroon                              72
# Canada                                 1
# Central African Republic            1129
# Chad                                 177
# China                                477
# Colombia                            1956
# Congo                               1330
# Costa Rica                             2
# Croatia                               19
# Cuba                               39946
# Dem. Rep. Congo                    25493
# Djibouti                               5
# Ecuador                               12
# Egypt                                 88
# El Salvador                            6
# Equatorial Guinea                     70
# Eritrea                            14645
# Estonia                               26
# Ethiopia                            8487
# France                                 1
# Gabon                                  8
# Gambia                                69
# Gaza Strip                             7
# Georgia                               95
# Germany                                1
# Ghana                                 14
# Guatemala                              5
# Guinea                                38
# Guinea - Bissau                        6
# Haiti                                 28
# Honduras                              25
# India                                 18
# Indonesia                             25
# Iran                               36683
# Iraq                              127326
# Israel                                 3
# Ivory Coast                          229
# Jamaica                                1
# Jordan                                39
# Kazakhstan                           550
# Kenya                                 60
# Korea, North                         191
# Kuwait                               109
# Kyrgyzstan                           285
# Laos                                6609
# Latvia                                66
# Lebanon                               11
# Liberia                             9424
# Libya                                  8
# Lithuania                             15
# Macedonia                              1
# Madagascar (Malagasy Republic)         4
# Malaysia                               6
# Mali                                  12
# Mauritania                           276
# Moldova                             4482
# Montenegro                             2
# Morocco                                7
# Namibia                                5
# Nepal                                183
# Netherlands                            2
# Niger                                  5
# Nigeria                              136
# Pakistan                            1210
# Palestine                           1817
# Philippines                            1
# Republic of South Sudan              181
# Russia                             15656
# Rwanda                              1516
# Saudi Arabia                           7
# Senegal                               20
# Serbia                                31
# Sierra Leone                        1364
# Somalia                            71120
# South Africa                           3
# Sri Lanka (Ceylon)                   536
# Sudan                              12636
# Sweden                                 1
# Syria                               2359
# Tajikistan                            21
# Tanzania                               4
# Thailand                              23
# Tibet                                 31
# Togo                                 401
# Tunisia                               12
# Turkey                                11
# Turkmenistan                          36
# Uganda                               267
# Ukraine                            11727
# United Arab Emirates                   1
# United Kingdom                         1
# Uzbekistan                          1800
# Venezuela                             17
# Vietnam                            10769
# Yemen                                112
# Zambia                                 1
# Zimbabwe                              67
# Name: arrivals, dtype: int64

# %%
ref_sum_df = arrivals_top20.to_frame().reset_index()
ref_sum_df.head()
# Out:
#     origin  arrivals
# 0    Burma    151875
# 1     Iraq    127326
# 2   Bhutan     85316
# 3  Somalia     71120
# 4     Cuba     39946

# %%
ref_sum_df = arrivals_top20.to_frame()

# %% [markdown]
# **Try it**
# Compute the top 10 states by total arrivals and save as `state_sum_df`.

# %%
# state_sum_df = (refugee_df.groupby('state')['arrivals']
#                                .sum()
#                                .sort_values(ascending=False)
#                                .head(10)
#                                .to_frame()
#                                .reset_index())
# state_sum_df

# %% [markdown]
# ## Lesson 5: Quick Visuals with pandas `.plot()`

# %% [markdown]
# ❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗❗

# %%
ax = ref_sum_df.plot(kind='barh', x='origin', y='arrivals', figsize=(12,6),
                      title='Total refugee arrivals by country of origin (Top 20)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'origin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1227743768.py in <cell line: 0>()
# ----> 1 ax = ref_sum_df.plot(kind='barh', x='origin', y='arrivals', figsize=(12,6),
#       2                       title='Total refugee arrivals by country of origin (Top 20)')
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     993                 if is_integer(x) and not data.columns._holds_integer():
#     994                     x = data_cols[x]
# --> 995                 elif not isinstance(data[x], ABCSeries):
#     996                     raise ValueError("x must be a label or position")
#     997                 data = data.set_index(x)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'origin'

# %% [markdown]
# **Try it**
# Make a line chart of total arrivals by year.

# %%
# total_by_year = refugee_df.groupby('year')['arrivals'].sum()
# ax = total_by_year.plot(kind='line', figsize=(10,5), title='Total arrivals by year')

# %% [markdown]
# ## Lesson 6: Interactive Charts with Plotly Express

# %%
# !pip -q install plotly
import plotly.express as px

# %% [markdown]
# ### Bar chart (interactive)

# %%
origin_sum = (refugee_df.groupby('origin')['arrivals']
               .sum().sort_values(ascending=False).head(15).reset_index())
fig = px.bar(origin_sum, x='origin', y='arrivals',
             title='Total refugee arrivals by origin (Top 15)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c5117c4d-a389-47e0-be2c-08f9eaaa9ae7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5117c4d-a389-47e0-be2c-08f9eaaa9ae7")) {                    Plotly.newPlot(                        "c5117c4d-a389-47e0-be2c-08f9eaaa9ae7",                        [{"alignmentgroup":"True","hovertemplate":"origin=%{x}\u003cbr\u003earrivals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Burma","Iraq","Bhutan","Somalia","Cuba","Iran","Dem. Rep. Congo","Russia","Eritrea","Sudan","Ukraine","Burundi","Vietnam","Liberia","Ethiopia"],"xaxis":"x","y":[151875,127326,85316,71120,39946,36683,25493,15656,14645,12636,11727,11152,10769,9424,8487],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{ ...

# %%
origin_sum = (refugee_df.groupby('origin')['arrivals']
               .sum().sort_values(ascending=False).head(15).reset_index())

# %%
fig = px.bar(origin_sum, x='origin', y='arrivals',
             title='Total refugee arrivals by origin (Top 15)')

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="65d76655-5163-4cb4-85b2-d8f15556af87" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65d76655-5163-4cb4-85b2-d8f15556af87")) {                    Plotly.newPlot(                        "65d76655-5163-4cb4-85b2-d8f15556af87",                        [{"alignmentgroup":"True","hovertemplate":"origin=%{x}\u003cbr\u003earrivals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Burma","Iraq","Bhutan","Somalia","Cuba","Iran","Dem. Rep. Congo","Russia","Eritrea","Sudan","Ukraine","Burundi","Vietnam","Liberia","Ethiopia"],"xaxis":"x","y":[151875,127326,85316,71120,39946,36683,25493,15656,14645,12636,11727,11152,10769,9424,8487],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{ ...

# %%
origin_sum
# Out:
#              origin  arrivals
# 0             Burma    151875
# 1              Iraq    127326
# 2            Bhutan     85316
# 3           Somalia     71120
# 4              Cuba     39946
# 5              Iran     36683
# 6   Dem. Rep. Congo     25493
# 7            Russia     15656
# 8           Eritrea     14645
# 9             Sudan     12636
# 10          Ukraine     11727
# 11          Burundi     11152
# 12          Vietnam     10769
# 13          Liberia      9424
# 14         Ethiopia      8487

# %% [markdown]
# ### Line chart (interactive)

# %%
total_by_year = refugee_df.groupby('year')['arrivals'].sum().reset_index()
fig = px.line(total_by_year, x='year', y='arrivals', markers=True,
              title='Total refugee arrivals by year (2005–2015)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="037091aa-b216-41f7-8be8-7de8229fcb5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("037091aa-b216-41f7-8be8-7de8229fcb5e")) {                    Plotly.newPlot(                        "037091aa-b216-41f7-8be8-7de8229fcb5e",                        [{"hovertemplate":"year=%{x}\u003cbr\u003earrivals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],"xaxis":"x","y":[51903,39552,47753,64734,79938,71362,51458,66292,66066,72820,60640],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scat ...

# %%
total_by_year = refugee_df.groupby('year')['arrivals'].sum().reset_index()

# %%
fig = px.line(total_by_year, x='year', y='arrivals', markers=True,
              title='Total refugee arrivals by year (2005–2015)')

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="64006782-a494-4057-a299-d2c04e68443b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64006782-a494-4057-a299-d2c04e68443b")) {                    Plotly.newPlot(                        "64006782-a494-4057-a299-d2c04e68443b",                        [{"hovertemplate":"year=%{x}\u003cbr\u003earrivals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],"xaxis":"x","y":[51903,39552,47753,64734,79938,71362,51458,66292,66066,72820,60640],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scat ...

# %% [markdown]
# ### Scatter with faceting

# %%
focus = refugee_df[refugee_df['origin'].isin(['Iraq','Somalia','Bhutan','Burma','Iran'])]
by_pair = focus.groupby(['origin','year'])['arrivals'].sum().reset_index()
fig = px.scatter(by_pair, x='year', y='arrivals', color='origin',
                 facet_col='origin', facet_col_wrap=3,
                 title='Yearly arrivals for selected origins')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="78143eae-dd36-429e-929a-8184f92321b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78143eae-dd36-429e-929a-8184f92321b3")) {                    Plotly.newPlot(                        "78143eae-dd36-429e-929a-8184f92321b3",                        [{"hovertemplate":"origin=Bhutan\u003cbr\u003eyear=%{x}\u003cbr\u003earrivals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bhutan","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Bhutan","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],"xaxis":"x4","y":[0,3,0,7544,15077,11729,14735,14459,9051,7476,5242],"yaxis":"y4","type":"scatter"},{"hovertemplate":"origin=Burma\u003cbr\u003eyear=%{x}\u003cbr\u003earrivals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Burma","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Burma","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],"xaxis":"x5","y":[1470,2294,14225,19000,19920,17176,15713,15112,14580,15971,16414],"yaxis":"y5","type":"scatter"},{"hovertemplate":"origin=Iran\u003cbr\u003eyear=%{x}\u003cbr\u003earrivals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Iran","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Iran","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],"xaxis":"x6","y":[1763,4065,5140,5067,5437,2979,2100,1973,2535,2830,2794],"yaxis":"y6","type":"scatter"},{"hovertemplate":"origin=Iraq\u003cbr\u003eyear=%{x}\u003cbr\u003earrivals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Iraq","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Iraq","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],"xaxis":"x","y":[204,218,2631,15766,19472,18251,6339,16369,18567,20337,9172],"yaxis":"y","type":"scatter"},{"hovertemplate":"origin=Somalia\u003cbr\u003eyear=%{x}\u003cbr\u003earrivals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Somalia","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Somalia","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],"xaxis":"x2","y":[9334,10522,5708,2698,4620,4401,3453,5893,7450,10057,6984],"yaxis":"y2","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{ ...

# %%
focus = refugee_df[refugee_df['origin'].isin(['Iraq','Somalia','Bhutan','Burma','Iran'])]
by_pair = focus.groupby(['origin','year'])['arrivals'].sum().reset_index()

# %%
fig = px.scatter(by_pair, x='year', y='arrivals', color='origin',
                 facet_col='origin', facet_col_wrap=3,
                 title='Yearly arrivals for selected origins')

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c8f87b11-a96a-4fbb-9a94-e9f22ae039a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8f87b11-a96a-4fbb-9a94-e9f22ae039a3")) {                    Plotly.newPlot(                        "c8f87b11-a96a-4fbb-9a94-e9f22ae039a3",                        [{"hovertemplate":"origin=Bhutan\u003cbr\u003eyear=%{x}\u003cbr\u003earrivals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bhutan","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Bhutan","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],"xaxis":"x4","y":[0,3,0,7544,15077,11729,14735,14459,9051,7476,5242],"yaxis":"y4","type":"scatter"},{"hovertemplate":"origin=Burma\u003cbr\u003eyear=%{x}\u003cbr\u003earrivals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Burma","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Burma","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],"xaxis":"x5","y":[1470,2294,14225,19000,19920,17176,15713,15112,14580,15971,16414],"yaxis":"y5","type":"scatter"},{"hovertemplate":"origin=Iran\u003cbr\u003eyear=%{x}\u003cbr\u003earrivals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Iran","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Iran","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],"xaxis":"x6","y":[1763,4065,5140,5067,5437,2979,2100,1973,2535,2830,2794],"yaxis":"y6","type":"scatter"},{"hovertemplate":"origin=Iraq\u003cbr\u003eyear=%{x}\u003cbr\u003earrivals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Iraq","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Iraq","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],"xaxis":"x","y":[204,218,2631,15766,19472,18251,6339,16369,18567,20337,9172],"yaxis":"y","type":"scatter"},{"hovertemplate":"origin=Somalia\u003cbr\u003eyear=%{x}\u003cbr\u003earrivals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Somalia","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Somalia","orientation":"v","showlegend":true,"x":[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],"xaxis":"x2","y":[9334,10522,5708,2698,4620,4401,3453,5893,7450,10057,6984],"yaxis":"y2","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{ ...

# %% [markdown]
# ## Save Artifacts (CSV)

# %%
refugee_df.to_csv('refugee_clean.csv', index=False)
try:
    from google.colab import files
    files.download('refugee_clean.csv')
except Exception:
    print('File saved to working directory.')

# %% [markdown]
# ---
# End of Workbook.
